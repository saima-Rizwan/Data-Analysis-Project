# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\Rizwan Ramzan\\Downloads\\Housing.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900  1.0  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671  2.0  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671  2.0  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622  3.0  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622  3.0  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 504  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786  1.0  273
# 505  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875  1.0  273
# 506  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675  1.0  273
# 507  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889  1.0  273
# 508  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050  1.0  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
new_df=df.head(50)
new_df
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900  1.0  296
# 1   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671  2.0  242
# 2   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671  2.0  242
# 3   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622  3.0  222
# 4   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622  3.0  222
# 5   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622  3.0  222
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605  5.0  311
# 7   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505  5.0  311
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821  5.0  311
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921  5.0  311
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467  5.0  311
# 11  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267  5.0  311
# ...

# %%
df.tail(50)
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD  TAX  \
# 459   6.80117  0.0  18.10     0  0.713  6.081  84.4  2.7175  24.0  666
# 460   4.81213  0.0  18.10     0  0.713  6.701  90.0  2.5975  24.0  666
# 461   3.69311  0.0  18.10     0  0.713  6.376  88.4  2.5671  24.0  666
# 462   6.65492  0.0  18.10     0  0.713  6.317  83.0  2.7344  24.0  666
# 463   5.82115  0.0  18.10     0  0.713  6.513  89.9  2.8016  24.0  666
# 464   7.83932  0.0  18.10     0  0.655  6.209  65.4  2.9634  24.0  666
# 465   3.16360  0.0  18.10     0  0.655  5.759  48.2  3.0665  24.0  666
# 466   3.77498  0.0  18.10     0  0.655  5.952  84.7  2.8715  24.0  666
# 467   4.42228  0.0  18.10     0  0.584  6.003  94.5  2.5403  24.0  666
# 468  15.57570  0.0  18.10     0  0.580  5.926  71.0  2.9084  24.0  666
# 469  13.07510  0.0  18.10     0  0.580  5.713  56.7  2.8237  24.0  666
# 470  13.07510  0.0  18.10     0  0.580  5.713  56.7  2.8237  24.0  666
# ...

# %%
new_df.info
# Out:
# <bound method DataFrame.info of        CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0   0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900  1.0  296     15.3
# 1   0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671  2.0  242     17.8
# 2   0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671  2.0  242     17.8
# 3   0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622  3.0  222     18.7
# 4   0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622  3.0  222     18.7
# ..      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...      ...
# 95  0.12204   0.0   2.89     0  0.445  6.625  57.8  3.4952  2.0  276     18.0
# 96  0.11504   0.0   2.89     0  0.445  6.163  69.6  3.4952  2.0  276     18.0
# 97  0.12083   0.0   2.89     0  0.445  8.069  76.0  3.4952  2.0  276     18.0
# 98  0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952  2.0  276     18.0
# 99  0.06860   0.0   2.89     0  0.445  7.416  62.5  3.4952  2.0  276     18.0
#
# ...

# %%
new_df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
new_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      3
# CHAS       0
# NOX        1
# RM         0
# AGE        0
# DIS        0
# RAD        1
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      1
# MEDV       0
# dtype: int64

# %%
new_df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
new_df.dropna(inplace=True)

# %%
new_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
new_df.describe()
# Out:
#             CRIM          ZN      INDUS  CHAS        NOX         RM  \
# count  94.000000   94.000000  94.000000  94.0  94.000000  94.000000
# mean    0.285998   11.526596   6.704255   0.0   0.472959   6.243968
# std     0.390361   21.513857   3.181089   0.0   0.046464   0.492387
# min     0.006320    0.000000   0.740000   0.0   0.398000   5.399000
# 25%     0.051197    0.000000   4.860000   0.0   0.439000   5.928500
# 50%     0.106775    0.000000   6.910000   0.0   0.453000   6.143500
# 75%     0.223610   17.875000   8.140000   0.0   0.524000   6.439000
# max     1.612820  100.000000  15.040000   0.0   0.538000   8.069000
#
#               AGE        DIS        RAD         TAX    PTRATIO           B  \
# count   94.000000  94.000000  94.000000   94.000000  94.000000   94.000000
# mean    58.109574   5.174479   3.989362  290.085106  18.702128  384.755106
# std     27.129043   1.445247   1.425533   46.319986   1.712131   28.151416
# ...

# %%
new_df['CRIM'].describe()
# Out:
# count    94.000000
# mean      0.285998
# std       0.390361
# min       0.006320
# 25%       0.051197
# 50%       0.106775
# 75%       0.223610
# max       1.612820
# Name: CRIM, dtype: float64

# %%
percentile25=new_df['CRIM'].quantile(0.25)

# %%
percentile75=new_df['CRIM'].quantile(0.75)

# %%
new_df[new_df['CRIM']>0.4822295]
# Out:
#        CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 13  0.62976  0.0   8.14     0  0.538  5.949   61.8  4.7075  4.0  307     21.0
# 14  0.63796  0.0   8.14     0  0.538  6.096   84.5  4.4619  4.0  307     21.0
# 15  0.62739  0.0   8.14     0  0.538  5.834   56.5  4.4986  4.0  307     21.0
# 16  1.05393  0.0   8.14     0  0.538  5.935   29.3  4.4986  NaN  307     21.0
# 17  0.78420  0.0   8.14     0  0.538  5.990   81.7  4.2579  4.0  307     21.0
# 18  0.80271  0.0   8.14     0  0.538  5.456   36.6  3.7965  4.0  307     21.0
# 19  0.72580  0.0   8.14     0  0.538  5.727   69.5  3.7965  4.0  307     21.0
# 20  1.25179  0.0   8.14     0  0.538  5.570   98.1  3.7979  4.0  307     21.0
# 21  0.85204  0.0   8.14     0  0.538  5.965   89.2  4.0123  4.0  307     21.0
# 22  1.23247  0.0   8.14     0  0.538  6.142   91.7  3.9769  4.0  307     21.0
# 23  0.98843  0.0   8.14     0  0.538  5.813  100.0  4.0952  4.0  307     21.0
# ...

# %%
new_df[new_df['CRIM']<-0.2074225]
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []
